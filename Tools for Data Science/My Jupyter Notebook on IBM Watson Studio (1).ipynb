# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tom Lewis-Clare**
# Job Seeking (Recent Graduate)

# %% [markdown]
# *I find the entire regression analysis process fulfilling and insightful. After used STATA to quantify the financial development and economic growth relationship for my dissertation, I have been searching for a role in data science since. But with an Economics degree rather than a more computer-focussed STEM degree, I can be held back from such a career, therefore I am trying to expand my skillset through completing this course.*

# %% [markdown]
# ### My code below will plot the curve y=-x.

# %%
a = [0, 1, 2, 3, 4]
b = [0, -1, -2, -3, -4]
import matplotlib.pyplot as plt
plt.plot(a,b)
plt.show()

# %% [markdown]
# <hr>
#
# | x | y |
# | -- | -- |
# | 0 | 0 |
# | 1 | -1 |
# | 2 | -2 |
# | 3 | -3 |
# | 4 | -4 |

# %% [markdown]
# <hr>
#
# - 1
# - 2
# - 3
# - 4

# %% [markdown]
# <hr>
#
# ~~ IBM Tools for Data Science ~~
